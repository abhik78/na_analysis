# %%
import pandas as pd

# %%
df = pd.read_csv('merged_test_angles.csv')

# %%
df.head()
# Out:
#    atom_labels          fragment_id       value  unusual  enough_hits  \
# 0   O22_P3_O17  4055189615:2:8158:2  105.697615     True         True
# 1   O36_P5_O31  4055189615:2:8158:2  103.148945     True         True
# 2  O57_C83_C82    107975654:2:866:4  110.624150    False         True
# 3   O15_P2_O10  4055189615:2:8158:2  103.381765     True         True
# 4   P2_O15_C21  1764748354:4:1586:4  120.505872    False         True
#
#       d_min  local_density   z_score   std_dev
# 0  0.927329       2.857143  4.387067  1.255384
# 1  0.893551       2.857143  2.356876  1.255384
# 2  0.841389      11.111111  0.671055  2.922160
# 3  0.660731       2.857143  2.542333  1.255384
# 4  0.597682      18.750000  0.532529  3.935257

# %%
df_bad = df.loc[df['z_score'] > 2.0]

# %%
df_bad.head()
# Out:
#     atom_labels          fragment_id       value  unusual  enough_hits  \
# 0    O22_P3_O17  4055189615:2:8158:2  105.697615     True         True
# 1    O36_P5_O31  4055189615:2:8158:2  103.148945     True         True
# 3    O15_P2_O10  4055189615:2:8158:2  103.381765     True         True
# 5    O48_P6_O43  4055189615:2:8158:2  103.500168     True         True
# 7  N60_C136_N59    689400660:2:767:2  119.114844     True         True
#
#       d_min  local_density   z_score   std_dev
# 0  0.927329       2.857143  4.387067  1.255384
# 1  0.893551       2.857143  2.356876  1.255384
# 3  0.660731       2.857143  2.542333  1.255384
# 5  0.542327       2.857143  2.636649  1.255384
# 7  0.316962       0.850492  4.019178  1.567694

# %%
df_bad['fragment_id'].value_counts()
# Out:
# 4055189615:2:8158:2    35
# 689400660:2:767:2      18
# 2839628158:3:676:3     17
# 1666947929:3:767:2     15
# 1803105184:1:866:3     14
#                        ..
# 2783505885:4:666:4      1
# 1211813948:3:767:3      1
# 91576925:4:676:3        1
# 400178609:3:667:3       1
# 2570380489:3:676:3      1
# Name: fragment_id, Length: 70, dtype: int64

# %%
df_bad['freq'] = df_bad.groupby('fragment_id')['fragment_id'].transform('count')
# Out:
# C:\Users\amukhopadhyay\AppData\Local\Continuum\anaconda3\envs\csd-python-2020\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_bad.head(20)
# Out:
#       atom_labels          fragment_id       value  unusual  enough_hits  \
# 0      O22_P3_O17  4055189615:2:8158:2  105.697615     True         True
# 1      O36_P5_O31  4055189615:2:8158:2  103.148945     True         True
# 3      O15_P2_O10  4055189615:2:8158:2  103.381765     True         True
# 5      O48_P6_O43  4055189615:2:8158:2  103.500168     True         True
# 7    N60_C136_N59    689400660:2:767:2  119.114844     True         True
# 11    O76_P10_O71  4055189615:2:8158:2  103.793875     True         True
# 14   N30_C121_N29    689400660:2:767:2  119.237380     True         True
# 15   N48_C130_N47    689400660:2:767:2  119.244807     True         True
# 20       O3_P1_O8  4055189615:2:8158:2  103.864547     True         True
# 22   N42_C129_N39    689400660:2:767:2  120.201866     True         True
# 23  C138_N60_C136   2839628158:3:676:3  121.331838     True         True
# 25     O62_P8_O57  4055189615:2:8158:2  104.182042     True         True
# ...
